# %%
#Import requests for web scraping
import pandas as pd
import requests as rq
import numpy as np
import collections

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

import matplotlib as mpl
import matplotlib.pyplot as plt

# import k-means from clustering stage
from PIL import Image 
from matplotlib import rcParams

print('Libraries installed')
# Out:
# Libraries installed

# %%
# Read the book with python
with open('TGofB_JA.txt') as f:
    text_book = f.read()
text_book

# %%
len(text_book)
# Out:
# 729169

# %%
# !pip3 -q install wordcloud #Library for wordcloud

# %%
# !pip3 -q install stop-words

# %%
from stop_words import get_stop_words #The words we want to ignore

stop_words_en = get_stop_words('en') #English StopWords

# %%
from wordcloud import WordCloud, STOPWORDS

print ('Wordcloud is installed and imported!')
# Out:
# Wordcloud is installed and imported!

# %%
stop_words = ['one','may','two','re','no.','et','al.,','the','The','In','J.','A.','I','also','R.','this',"it's","It's",'it','"The','A'] + stop_words_en #Adding aditional StopWords
#initiate world cloud object
genius_wc = WordCloud(
    background_color='white',
    max_words=700000,
    stopwords=stop_words   # change stop_words_en for stop_words
)

# generate the word cloud
genius_wc.generate(data)

# %%
# display the word cloud
plt.imshow(genius_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# save mask to pigeon_mask
pigeon_mask = np.array(Image.open('pigeon.png'))
    
print('Image downloaded and saved!')
# Out:
# Image downloaded and saved!

# %%
pigeon_mask

# %%
fig = plt.figure()
fig.set_figwidth(12) # set width
fig.set_figheight(16) # set height

plt.imshow(pigeon_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# instantiate a word cloud object
genius_wc = WordCloud(background_color='white', max_words=700000, mask=pigeon_mask, stopwords=stop_words)

# generate the word cloud
genius_wc.generate(data)

# display the word cloud
fig = plt.figure()
fig.set_figwidth(14) # set width
fig.set_figheight(18) # set height


plt.imshow(genius_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
filtered_words = [word for word in data.split() if word not in stop_words]
counted_words = collections.Counter(filtered_words)

words = []
counts = []
for letter, count in counted_words.most_common(10):
    words.append(letter)
    counts.append(count)

# %%
colors = cm.rainbow(np.linspace(0, 1, 20))
rcParams['figure.figsize'] = 20, 10

plt.title('Top words in the text vs their count')
plt.xlabel('Count')
plt.ylabel('Words')
plt.barh(words, counts, color=colors)
# Out:
# <BarContainer object of 10 artists>

# %%
print("The Genius Of Birds")
# Out:
# The Genius Of Birds
